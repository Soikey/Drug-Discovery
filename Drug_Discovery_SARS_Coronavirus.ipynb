# %% [markdown]
# <a href="https://colab.research.google.com/github/Soikey/Drug-Discovery/blob/main/Drug_Discovery_SARS_Coronavirus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.3.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.11/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.1.31)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.1.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.17.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.6 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 1.2 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.5 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-24.1.2 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                                           organism  \
# 0               []                                        Coronavirus
# 1               []                                 Feline coronavirus
# 2               []                                 Murine coronavirus
# 3               []                                 Canine coronavirus
# 4               []                             Human coronavirus 229E
# 5               []                             Human coronavirus OC43
# 6               []  Severe acute respiratory syndrome-related coro...
# 7               []  Middle East respiratory syndrome-related coron...
# 8               []  Severe acute respiratory syndrome-related coro...
# 9               []    Severe acute respiratory syndrome coronavirus 2
#
#                                            pref_name  score  \
# 0                                        Coronavirus   17.0
# 1                                 Feline coronavirus   14.0
# 2                                 Murine coronavirus   14.0
# 3                                 Canine coronavirus   14.0
# 4                             Human coronavirus 229E   13.0
# 5                             Human coronavirus OC43   13.0
# 6                SARS coronavirus 3C-like proteinase   10.0
# 7  Middle East respiratory syndrome-related coron...    9.0
# 8                          Replicase polyprotein 1ab    4.0
# 9                          Replicase polyprotein 1ab    4.0
#
#    species_group_flag target_chembl_id  \
# 0               False     CHEMBL613732
# 1               False     CHEMBL612744
# 2               False    CHEMBL5209664
# 3               False    CHEMBL5291668
# 4               False     CHEMBL613837
# 5               False    CHEMBL5209665
# 6               False       CHEMBL3927
# 7               False    CHEMBL4296578
# 8               False       CHEMBL5118
# 9               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0                                                 []        ORGANISM    11119
# 1                                                 []        ORGANISM    12663
# 2                                                 []        ORGANISM   694005
# 3                                                 []        ORGANISM    11153
# 4                                                 []        ORGANISM    11137
# 5                                                 []        ORGANISM    31631
# 6  [{'accession': 'P0C6U8', 'component_descriptio...  SINGLE PROTEIN   694009
# 7                                                 []        ORGANISM  1335626
# 8  [{'accession': 'P0C6X7', 'component_descriptio...  SINGLE PROTEIN   694009
# 9  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
# SARS coronavirus 3C-like proteinase
selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL5209665'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head()
# Out:
#   action_type activity_comment  activity_id  \
# 0        None             None     22849695
# 1        None             None     22849696
# 2        None             None     22849697
# 3        None             None     23254378
# 4        None             None     24383469
#
#                                  activity_properties assay_chembl_id  \
# 0  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4723190
# 1  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4723190
# 2  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4723190
# 3  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4831805
# 4  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5039295
#
#                                    assay_description assay_type  \
# 0  Antiviral activity against HCoV-OC43 infected ...          F
# 1  Antiviral activity against HCoV-OC43 infected ...          F
# 2  Antiviral activity against HCoV-OC43 infected ...          F
# 3  Antiviral activity against HCoV-OC43 infected ...          F
# 4  Antiviral activity against HCoV-OC43 assessed ...          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
# 3                    None                   None  BAO_0000190  ...
# 4                    None                   None  BAO_0000190  ...
#
#           target_organism        target_pref_name target_tax_id text_value  \
# 0  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 1  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 2  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 3  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 4  Human coronavirus OC43  Human coronavirus OC43         31631       None
#
#    toid  type units    uo_units upper_value value
# 0  None  IC50    uM  UO_0000065        None  0.72
# 1  None  IC50    uM  UO_0000065        None  0.91
# 2  None  IC50    uM  UO_0000065        None  0.29
# 3  None  IC50    uM  UO_0000065        None   0.7
# 4  None  IC50    uM  UO_0000065        None  20.0
#
# [5 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('sars_corona_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#   action_type activity_comment  activity_id  \
# 0        None             None     22849695
# 1        None             None     22849696
# 2        None             None     22849697
# 3        None             None     23254378
# 4        None             None     24383469
# 5        None             None     24383470
# 6        None             None     24383471
# 7        None             None     24383472
# 8        None             None     24992668
#
#                                  activity_properties assay_chembl_id  \
# 0  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4723190
# 1  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4723190
# 2  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4723190
# 3  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL4831805
# 4  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5039295
# 5  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5039295
# 6  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5039296
# 7  [{'comments': None, 'relation': '=', 'result_f...   CHEMBL5039296
# 8                                                 []   CHEMBL5230454
#
#                                    assay_description assay_type  \
# 0  Antiviral activity against HCoV-OC43 infected ...          F
# 1  Antiviral activity against HCoV-OC43 infected ...          F
# 2  Antiviral activity against HCoV-OC43 infected ...          F
# 3  Antiviral activity against HCoV-OC43 infected ...          F
# 4  Antiviral activity against HCoV-OC43 assessed ...          F
# 5  Antiviral activity against HCoV-OC43 assessed ...          F
# 6  Antiviral activity against HCoV-OC43 assessed ...          F
# 7  Antiviral activity against HCoV-OC43 assessed ...          F
# 8  Antiviral activity against HCoV-OC43 assessed ...          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
# 3                    None                   None  BAO_0000190  ...
# 4                    None                   None  BAO_0000190  ...
# 5                    None                   None  BAO_0000190  ...
# 6                    None                   None  BAO_0000190  ...
# 7                    None                   None  BAO_0000190  ...
# 8                    None                   None  BAO_0000190  ...
#
#           target_organism        target_pref_name target_tax_id text_value  \
# 0  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 1  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 2  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 3  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 4  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 5  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 6  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 7  Human coronavirus OC43  Human coronavirus OC43         31631       None
# 8  Human coronavirus OC43  Human coronavirus OC43         31631       None
#
#    toid  type units    uo_units upper_value value
# 0  None  IC50    uM  UO_0000065        None  0.72
# 1  None  IC50    uM  UO_0000065        None  0.91
# 2  None  IC50    uM  UO_0000065        None  0.29
# 3  None  IC50    uM  UO_0000065        None   0.7
# 4  None  IC50    uM  UO_0000065        None  20.0
# 5  None  IC50    uM  UO_0000065        None  0.28
# 6  None  IC50    uM  UO_0000065        None  20.0
# 7  None  IC50    uM  UO_0000065        None  0.97
# 8  None  IC50    uM  UO_0000065        None  1.81
#
# [9 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 4695

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  ... upper_value value
# 0                None        33969  ...        None  0.75
# 1                None        37563  ...        None   0.1
# 2                None        37565  ...        None  50.0
# 3                None        38902  ...        None   0.3
# 4                None        41170  ...        None   0.8
# ...               ...          ...  ...         ...   ...
# 7019             None     18798884  ...        None  2.44
# 7020             None     18798885  ...        None  2.54
# 7021             None     18798886  ...        None  3.81
# 7022             None     18798887  ...        None  3.46
# 7023             None     18798888  ...        None  2.78
#
# [4695 rows x 43 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-05c7446f9a3a> in <cell line: 0>()
#       1 selection = ['molecule_chembl_id','canonical_smiles','standard_value']
# ----> 2 df3 = df2_nr[selection]
#       3 df3
#
# NameError: name 'df2_nr' is not defined

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id  ...         class
# 0          CHEMBL133897  ...        active
# 1          CHEMBL336398  ...        active
# 2          CHEMBL131588  ...      inactive
# 3          CHEMBL130628  ...        active
# 4          CHEMBL130478  ...        active
# ...                 ...  ...           ...
# 4690      CHEMBL4293155  ...  intermediate
# 4691      CHEMBL4282558  ...  intermediate
# 4692      CHEMBL4281727  ...  intermediate
# 4693      CHEMBL4292349  ...  intermediate
# 4694      CHEMBL4278260  ...  intermediate
#
# [4695 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 90%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 4668
# -rw-r--r-- 1 root root 3562870 Jun  1 15:03 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  342989 Jun  1 15:03 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  385924 Jun  1 15:03 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  475843 Jun  1 15:03 acetylcholinesterase.zip
# drwxr-xr-x 1 root root    4096 May 27 16:27 sample_data

# %% [markdown]
# ---
